# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer

df = pd.read_csv('train.csv')
df = df.dropna(subset=['Style', 'Color', 'Brand', 'Material'])
df_test = pd.read_csv('test.csv')
df.columns = df.columns.str.replace(' ', '_')
df_test.columns = df_test.columns.str.replace(' ', '_')

# %%
print(df.isna().sum())
print(df.shape)
# Out:
# id                         0
# Brand                      0
# Material                   0
# Size                    6101
# Compartments               0
# Laptop_Compartment      6722
# Waterproof              6510
# Style                      0
# Color                      0
# Weight_Capacity_(kg)      48
# Price                      0
# dtype: int64
# (265771, 11)

# %% [markdown]
# ## Pipelines

# %%
impute_onehot = Pipeline([
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])
impute_onehot.set_output(transform="pandas")
impute_onehot_cols = ['Style', 'Color', 'Brand', 'Material']

size_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='Medium')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
]) 
size_pipeline.set_output(transform="pandas")
size_pipeline_cols = ['Size']

yes_no_pipeline = Pipeline([
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
]) 
yes_no_pipeline.set_output(transform="pandas")
yes_no_pipeline_cols = ['Waterproof', 'Laptop_Compartment']

weight_pipeline = Pipeline([
    ('medianimputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
weight_pipeline.set_output(transform="pandas")
weight_pipeline_cols = ['Weight_Capacity_(kg)']

compartments_pipeline = Pipeline([
    ('imputer', KNNImputer(n_neighbors=3)), 
    ('scaler', StandardScaler())
])
compartments_pipeline.set_output(transform='pandas')
compartments_pipeline_cols = ['Compartments']

# %% [markdown]
# ## Column Transformer

# %%
preprocessor = ColumnTransformer([
    ('style_color_brand_material', impute_onehot, impute_onehot_cols),
    ('size', size_pipeline, size_pipeline_cols),
    ('waterproof_laptopcompartment', yes_no_pipeline, yes_no_pipeline_cols),
    ('weight_pipeline', weight_pipeline, weight_pipeline_cols),
    ('compartments', compartments_pipeline, compartments_pipeline_cols)
])
preprocessor.set_output(transform='pandas')
# Out:
# ColumnTransformer(transformers=[('style_color_brand_material',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['Style', 'Color', 'Brand', 'Material']),
#                                 ('size',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='Medium',
#                                                                 strategy='constant')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_va...
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['Waterproof', 'Laptop_Compartment']),
#                                 ('weight_pipeline',
#                                  Pipeline(steps=[('medianimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Weight_Capacity_(kg)']),
#                                 ('compartments',
#                                  Pipeline(steps=[('imputer',
#                                                   KNNImputer(n_neighbors=3)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Compartments'])])

# %% [markdown]
# ## Split

# %%
from sklearn.model_selection import train_test_split

id_col = 'id'
target_col = 'Price'
y = df[target_col]
X = df.drop([id_col,target_col],axis=1)

X_transformed = preprocessor.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X_transformed, y, test_size=0.2, random_state=13)

# %% [markdown]
# # Simple models
# ### Wybór modeli:
# - XGBRegressor
# - LightGBM
# - XGBoost
# - CatBoost
# - KNN Imputer (?)

# %% [markdown]
# # Prepare Test Data

# %%
test_id_col=df_test.id
X_test= df_test.drop('id',axis=1)
X_test_transformed = preprocessor.fit_transform(X_test)

# %% [markdown]
# # XGBRegressor + Optuna (Basic)

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import root_mean_squared_error

def objective(trial):
    max_depth=trial.suggest_int('max_depth',3,7)
    learning_rate=trial.suggest_float('learning_rate', 0.01,0.1)
    min_child_weight = trial.suggest_float('min_child_weight', 0.01,1)
    subsample = trial.suggest_float('subsample', 0.1,1.0)
    colsample_bylevel= trial.suggest_float("colsample_bylevel", 0.1, 1)
    colsample_bytree= trial.suggest_float("colsample_bytree", 0.1, 1)
    colsample_bynode= trial.suggest_float("colsample_bynode", 0.1, 1)
    reg_alpha= trial.suggest_float("reg_alpha", 0.01, 1)
    reg_lambda= trial.suggest_float("reg_lambda", 0.01, 1)

    model = XGBRegressor(n_estimators=100,
                         max_depth=max_depth,
                         learning_rate=learning_rate,
                         min_child_weight=min_child_weight,
                         subsample=subsample,
                         colsample_bylevel=colsample_bylevel,
                         colsample_bynode=colsample_bynode,
                         colsample_bytree=colsample_bytree,
                         reg_alpha=reg_alpha,
                         reg_lambda=reg_lambda)
    score = cross_val_score(model, X_train,y_train, cv=5, scoring='neg_root_mean_squared_error')
    return score.mean()

study =optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30, show_progress_bar=True )

# [I 2025-02-11 00:06:14,659] Trial 23 finished with value: -39.0235015574814 and parameters: {'max_depth': 4, 'learning_rate': 0.047088991461490495, 'min_child_weight': 0.15280074473565008, 'subsample': 0.8823981209895368, 'colsample_bylevel': 0.38194915435768984, 'colsample_bytree': 0.8872938771302274, 'colsample_bynode': 0.8920539233861519, 'reg_alpha': 0.5677685341501635, 'reg_lambda': 0.519321143067285}. Best is trial 23 with value: -39.0235015574814.
# Out:
# [I 2025-02-11 00:18:03,831] A new study created in memory with name: no-name-f536a329-e97a-4d2a-b4ae-c75f120062d0
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-02-11 00:18:06,180] Trial 0 finished with value: -38.93352499681244 and parameters: {'max_depth': 4, 'learning_rate': 0.09738165129336883, 'min_child_weight': 0.2953756913063758, 'subsample': 0.7582721732175878, 'colsample_bylevel': 0.9834579108629342, 'colsample_bytree': 0.7699614459671464, 'colsample_bynode': 0.9782418105940006, 'reg_alpha': 0.9574220931075091, 'reg_lambda': 0.30182695674706067}. Best is trial 0 with value: -38.93352499681244.
# [I 2025-02-11 00:18:08,246] Trial 1 finished with value: -38.924711406752 and parameters: {'max_depth': 3, 'learning_rate': 0.03299787637727764, 'min_child_weight': 0.7797357630455212, 'subsample': 0.5710795201240312, 'colsample_bylevel': 0.9271931247022445, 'colsample_bytree': 0.9842634846356743, 'colsample_bynode': 0.2911023112880643, 'reg_alpha': 0.06746931789427571, 'reg_lambda': 0.9619605957355585}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:10,524] Trial 2 finished with value: -38.92962777603618 and parameters: {'max_depth': 5, 'learning_rate': 0.08895131652250375, 'min_child_weight': 0.9057553288034518, 'subsample': 0.22316542002424672, 'colsample_bylevel': 0.5025876005320795, 'colsample_bytree': 0.3825328164064906, 'colsample_bynode': 0.3232609846201531, 'reg_alpha': 0.9769696219493842, 'reg_lambda': 0.3843604863531895}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:13,821] Trial 3 finished with value: -38.92989206830308 and parameters: {'max_depth': 7, 'learning_rate': 0.03422953418937607, 'min_child_weight': 0.7501989958376278, 'subsample': 0.4229266158162913, 'colsample_bylevel': 0.6786165870148292, 'colsample_bytree': 0.5395512038045445, 'colsample_bynode': 0.3832496394520848, 'reg_alpha': 0.8426985727031844, 'reg_lambda': 0.5305383649171512}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:15,973] Trial 4 finished with value: -38.93353971518373 and parameters: {'max_depth': 4, 'learning_rate': 0.028015170665494294, 'min_child_weight': 0.5977757932727285, 'subsample': 0.2014782169313558, 'colsample_bylevel': 0.20547094183458814, 'colsample_bytree': 0.33191654186718367, 'colsample_bynode': 0.611067312866759, 'reg_alpha': 0.7451698139523526, 'reg_lambda': 0.7853245530300013}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:19,202] Trial 5 finished with value: -38.94076380532833 and parameters: {'max_depth': 6, 'learning_rate': 0.04568729667366576, 'min_child_weight': 0.765590041203877, 'subsample': 0.5037506074319392, 'colsample_bylevel': 0.7256173461488012, 'colsample_bytree': 0.9484720787702833, 'colsample_bynode': 0.9160078723125362, 'reg_alpha': 0.8960108577049933, 'reg_lambda': 0.8589251968144815}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:21,141] Trial 6 finished with value: -38.92800501821083 and parameters: {'max_depth': 4, 'learning_rate': 0.047615581146902924, 'min_child_weight': 0.9833073593057592, 'subsample': 0.4345989005501212, 'colsample_bylevel': 0.20554345818269848, 'colsample_bytree': 0.8140163458953593, 'colsample_bynode': 0.2844384223238224, 'reg_alpha': 0.021788771416989063, 'reg_lambda': 0.2954938433283391}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:23,693] Trial 7 finished with value: -38.92554621386156 and parameters: {'max_depth': 5, 'learning_rate': 0.03631678369427093, 'min_child_weight': 0.9526358620450238, 'subsample': 0.343816115327891, 'colsample_bylevel': 0.5518704168848291, 'colsample_bytree': 0.38703461289803215, 'colsample_bynode': 0.8784103706828067, 'reg_alpha': 0.4003576653613715, 'reg_lambda': 0.9339818515378278}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:25,956] Trial 8 finished with value: -38.94183092820751 and parameters: {'max_depth': 7, 'learning_rate': 0.09318855134506081, 'min_child_weight': 0.39398092476768015, 'subsample': 0.11884699851310138, 'colsample_bylevel': 0.1082945447646132, 'colsample_bytree': 0.4666848510219155, 'colsample_bynode': 0.2598964200665003, 'reg_alpha': 0.5741281206251759, 'reg_lambda': 0.6269834543408802}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:28,286] Trial 9 finished with value: -38.9270166571187 and parameters: {'max_depth': 4, 'learning_rate': 0.027790921067942367, 'min_child_weight': 0.4070740627706912, 'subsample': 0.30466432832004015, 'colsample_bylevel': 0.2405860061188351, 'colsample_bytree': 0.8338791109740606, 'colsample_bynode': 0.5349420451709889, 'reg_alpha': 0.9466006169758391, 'reg_lambda': 0.39572284800959123}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:29,880] Trial 10 finished with value: -38.93945958135315 and parameters: {'max_depth': 3, 'learning_rate': 0.010927295272419181, 'min_child_weight': 0.027154295661022565, 'subsample': 0.9995555991207564, 'colsample_bylevel': 0.9640886442933524, 'colsample_bytree': 0.11750252667182132, 'colsample_bynode': 0.13961119510430786, 'reg_alpha': 0.02674467007435246, 'reg_lambda': 0.040112271005650235}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:31,750] Trial 11 finished with value: -38.92765578482046 and parameters: {'max_depth': 3, 'learning_rate': 0.06690297361896705, 'min_child_weight': 0.7832575309612608, 'subsample': 0.6276809374737319, 'colsample_bylevel': 0.450683216589555, 'colsample_bytree': 0.20207750882485576, 'colsample_bynode': 0.7266328226564207, 'reg_alpha': 0.2722054976864873, 'reg_lambda': 0.9954602307726607}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:34,067] Trial 12 finished with value: -38.93354732797768 and parameters: {'max_depth': 5, 'learning_rate': 0.06583620035554683, 'min_child_weight': 0.6256089341005349, 'subsample': 0.6796001798075896, 'colsample_bylevel': 0.7240589365388792, 'colsample_bytree': 0.6647553385155678, 'colsample_bynode': 0.7850353262029919, 'reg_alpha': 0.29822368537286537, 'reg_lambda': 0.9946122622571472}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:36,787] Trial 13 finished with value: -38.928405846549154 and parameters: {'max_depth': 6, 'learning_rate': 0.011163399716760346, 'min_child_weight': 0.888502168125292, 'subsample': 0.8039695294214222, 'colsample_bylevel': 0.8468330161229712, 'colsample_bytree': 0.9919898986973097, 'colsample_bynode': 0.488679982301291, 'reg_alpha': 0.30207932790757774, 'reg_lambda': 0.7875838390801301}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:38,897] Trial 14 finished with value: -38.930139128338546 and parameters: {'max_depth': 3, 'learning_rate': 0.039819300477305794, 'min_child_weight': 0.9902019193425288, 'subsample': 0.34708785162022227, 'colsample_bylevel': 0.3915204785020163, 'colsample_bytree': 0.6433232815536234, 'colsample_bynode': 0.11264711235670649, 'reg_alpha': 0.469516625950103, 'reg_lambda': 0.6862058016458448}. Best is trial 1 with value: -38.924711406752.
# [I 2025-02-11 00:18:41,279] Trial 15 finished with value: -38.92347506733984 and parameters: {'max_depth': 6, 'learning_rate': 0.05978314604907063, 'min_child_weight': 0.6414233079680471, 'subsample': 0.5732840136301172, 'colsample_bylevel': 0.6061577309911116, 'colsample_bytree': 0.2527216226200123, 'colsample_bynode': 0.7948891440755895, 'reg_alpha': 0.12814458486632413, 'reg_lambda': 0.9176301025693665}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:43,929] Trial 16 finished with value: -38.92722929390642 and parameters: {'max_depth': 6, 'learning_rate': 0.05896105242645495, 'min_child_weight': 0.6040489837172603, 'subsample': 0.5690821979052446, 'colsample_bylevel': 0.8496840509197984, 'colsample_bytree': 0.26170074991582737, 'colsample_bynode': 0.6636449382377658, 'reg_alpha': 0.1534350336911796, 'reg_lambda': 0.7019468350609757}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:45,727] Trial 17 finished with value: -38.92369264937406 and parameters: {'max_depth': 6, 'learning_rate': 0.08174878988052353, 'min_child_weight': 0.49110967254054627, 'subsample': 0.8612662932597374, 'colsample_bylevel': 0.6066310262536755, 'colsample_bytree': 0.10290990376559911, 'colsample_bynode': 0.7709448720262623, 'reg_alpha': 0.16379585600071073, 'reg_lambda': 0.8641786181066002}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:47,692] Trial 18 finished with value: -38.923545458320156 and parameters: {'max_depth': 6, 'learning_rate': 0.07756521029504068, 'min_child_weight': 0.20846341755718073, 'subsample': 0.9393692346903962, 'colsample_bylevel': 0.5929621459362747, 'colsample_bytree': 0.10360837805556017, 'colsample_bynode': 0.8150390322711694, 'reg_alpha': 0.16135072680980378, 'reg_lambda': 0.8336827223920227}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:49,931] Trial 19 finished with value: -38.924436742428256 and parameters: {'max_depth': 7, 'learning_rate': 0.07743003702783573, 'min_child_weight': 0.11128422372282826, 'subsample': 0.9558931907746637, 'colsample_bylevel': 0.35408763199081367, 'colsample_bytree': 0.21673343201478779, 'colsample_bynode': 0.8701505318093345, 'reg_alpha': 0.18698639397163358, 'reg_lambda': 0.5686516097695085}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:52,454] Trial 20 finished with value: -38.92765342012106 and parameters: {'max_depth': 6, 'learning_rate': 0.07705047589077998, 'min_child_weight': 0.24183584567391225, 'subsample': 0.8934389705211647, 'colsample_bylevel': 0.6133870610549746, 'colsample_bytree': 0.2886114242379444, 'colsample_bynode': 0.6815998810199767, 'reg_alpha': 0.5997359253741269, 'reg_lambda': 0.7649714574309296}. Best is trial 15 with value: -38.92347506733984.
# [I 2025-02-11 00:18:54,421] Trial 21 finished with value: -38.9233387996237 and parameters: {'max_depth': 6, 'learning_rate': 0.08181528126081396, 'min_child_weight': 0.489545899514931, 'subsample': 0.8250598136737485, 'colsample_bylevel': 0.5862187701087278, 'colsample_bytree': 0.11712309627532602, 'colsample_bynode': 0.7799950298005496, 'reg_alpha': 0.12046121248851688, 'reg_lambda': 0.8798346044815257}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:18:56,318] Trial 22 finished with value: -38.92898955753219 and parameters: {'max_depth': 6, 'learning_rate': 0.06893936422426414, 'min_child_weight': 0.21550891371174874, 'subsample': 0.7150798035314142, 'colsample_bylevel': 0.6431141274222406, 'colsample_bytree': 0.16197312693531266, 'colsample_bynode': 0.8222553059788849, 'reg_alpha': 0.11066367385338848, 'reg_lambda': 0.8864409956441685}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:18:58,395] Trial 23 finished with value: -38.92534237863625 and parameters: {'max_depth': 7, 'learning_rate': 0.08612440525821502, 'min_child_weight': 0.4896783907613527, 'subsample': 0.8598242438050708, 'colsample_bylevel': 0.5124375264977538, 'colsample_bytree': 0.18051649884635895, 'colsample_bynode': 0.9202796033297553, 'reg_alpha': 0.23135321781936144, 'reg_lambda': 0.8381153920831087}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:00,593] Trial 24 finished with value: -38.92654916988572 and parameters: {'max_depth': 5, 'learning_rate': 0.05638882355292732, 'min_child_weight': 0.3522035839410548, 'subsample': 0.9285396946684084, 'colsample_bylevel': 0.7913800973488448, 'colsample_bytree': 0.10683401608017812, 'colsample_bynode': 0.9747545685851765, 'reg_alpha': 0.35842218274518534, 'reg_lambda': 0.7118730687471593}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:02,916] Trial 25 finished with value: -38.92633121452641 and parameters: {'max_depth': 6, 'learning_rate': 0.07206425995642633, 'min_child_weight': 0.6821744739021345, 'subsample': 0.7938446417128697, 'colsample_bylevel': 0.42904174338282725, 'colsample_bytree': 0.2578935954939161, 'colsample_bynode': 0.6160442828563245, 'reg_alpha': 0.14110114316032252, 'reg_lambda': 0.9153607688620865}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:06,064] Trial 26 finished with value: -38.92763544810305 and parameters: {'max_depth': 7, 'learning_rate': 0.0615904434408632, 'min_child_weight': 0.14857534322322408, 'subsample': 0.6400489485896392, 'colsample_bylevel': 0.5518198649635019, 'colsample_bytree': 0.3494350353942805, 'colsample_bynode': 0.7314684854097719, 'reg_alpha': 0.4250670760610846, 'reg_lambda': 0.6497054707735412}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:08,638] Trial 27 finished with value: -38.92747274356752 and parameters: {'max_depth': 6, 'learning_rate': 0.051589960205187496, 'min_child_weight': 0.5611416923507703, 'subsample': 0.997354138014668, 'colsample_bylevel': 0.32443698166243184, 'colsample_bytree': 0.4486295983222726, 'colsample_bynode': 0.8352419388759023, 'reg_alpha': 0.09590304215529846, 'reg_lambda': 0.0862822008750479}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:10,936] Trial 28 finished with value: -38.92651632406093 and parameters: {'max_depth': 5, 'learning_rate': 0.07753991926276949, 'min_child_weight': 0.6897336939134573, 'subsample': 0.7462850373504392, 'colsample_bylevel': 0.717719701718283, 'colsample_bytree': 0.1619858675812107, 'colsample_bynode': 0.5605779625397278, 'reg_alpha': 0.23666639921559668, 'reg_lambda': 0.8018854020803946}. Best is trial 21 with value: -38.9233387996237.
# [I 2025-02-11 00:19:13,459] Trial 29 finished with value: -38.92546034456798 and parameters: {'max_depth': 5, 'learning_rate': 0.09558573094154059, 'min_child_weight': 0.3031678322972347, 'subsample': 0.8225939829633686, 'colsample_bylevel': 0.584554763433473, 'colsample_bytree': 0.29234909748907456, 'colsample_bynode': 0.987752475120284, 'reg_alpha': 0.35011303993489595, 'reg_lambda': 0.22103071948131497}. Best is trial 21 with value: -38.9233387996237.

# %%
xgb = XGBRegressor(n_estimators=100,
                         max_depth=4,
                         learning_rate=0.047088991461490495,
                         min_child_weight=0.15280074473565008,
                         subsample=0.8823981209895368,
                         colsample_bylevel=0.38194915435768984,
                         colsample_bynode=0.8920539233861519,
                         colsample_bytree=0.8872938771302274,
                         reg_alpha=0.5677685341501635,
                         reg_lambda=0.519321143067285)
xgb.fit(X_train, y_train)
test_predicted = xgb.predict(X_test_transformed)
submission = pd.DataFrame({
    'id': test_id_col,
    'Price': test_predicted
})
submission.to_csv('submission-xgb-weight_median-testing-hparams.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 12
#       1 xgb = XGBRegressor(n_estimators=100,
#       2                          max_depth=4,
#       3                          learning_rate=0.047088991461490495,
#    (...)
#       9                          reg_alpha=0.5677685341501635,
#      10                          reg_lambda=0.519321143067285)
#      11 xgb.fit(X_train, y_train)
# ---> 12 test_predicted = xgb.predict(X_test_transformed)
#      13 submission = pd.DataFrame({
#      14     'id': test_id_col,
#      15     'Price': test_predicted
#      16 })
#      17 submission.to_csv('submission-xgb-weight_median-testing-hparams.csv', index=False)
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['style_color_brand_material__Style_Backpack', 'style_color_brand_material__Style_Messenger', 'style_color_brand_material__Style_Tote', 'style_color_brand_material__Color_Black', 'style_color_brand_material__Color_Blue', 'style_color_brand_material__Color_Gray', 'style_color_brand_material__Color_Green', 'style_color_brand_material__Color_Pink', 'style_color_brand_material__Color_Red', 'style_color_brand_material__Brand_Adidas', 'style_color_brand_material__Brand_Jansport', 'style_color_brand_material__Brand_Nike', 'style_color_brand_material__Brand_Puma', 'style_color_brand_material__Brand_Under Armour', 'style_color_brand_material__Material_Canvas', 'style_color_brand_material__Material_Leather', 'style_color_brand_material__Material_Nylon', 'style_color_brand_material__Material_Polyester', 'size__Size', 'waterproof_laptopcompartment__Waterproof', 'waterproof_laptopcompartment__Laptop_Compartment', 'weight_pipeline__Weight_Capacity_(kg)', 'compartments__Compartments'] ['style_color_brand_material__Style_Backpack', 'style_color_brand_material__Style_Messenger', 'style_color_brand_material__Style_Tote', 'style_color_brand_material__Style_nan', 'style_color_brand_material__Color_Black', 'style_color_brand_material__Color_Blue', 'style_color_brand_material__Color_Gray', 'style_color_brand_material__Color_Green', 'style_color_brand_material__Color_Pink', 'style_color_brand_material__Color_Red', 'style_color_brand_material__Color_nan', 'style_color_brand_material__Brand_Adidas', 'style_color_brand_material__Brand_Jansport', 'style_color_brand_material__Brand_Nike', 'style_color_brand_material__Brand_Puma', 'style_color_brand_material__Brand_Under Armour', 'style_color_brand_material__Brand_nan', 'style_color_brand_material__Material_Canvas', 'style_color_brand_material__Material_Leather', 'style_color_brand_material__Material_Nylon', 'style_color_brand_material__Material_Polyester', 'style_color_brand_material__Material_nan', 'size__Size', 'waterproof_laptopcompartment__Waterproof', 'waterproof_laptopcompartment__Laptop_Compartment', 'weight_pipeline__Weight_Capacity_(kg)', 'compartments__Compartments']
# training data did not have the following fields: style_color_brand_material__Style_nan, style_color_brand_material__Color_nan, style_color_brand_material__Brand_nan, style_color_brand_material__Material_nan

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMRegressor
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.metrics import root_mean_squared_error

def objective(trial):
    n_estimators=trial.suggest_int('n_estimators',100,800)
    max_depth=trial.suggest_int('max_depth',3,15)
    num_leaves=trial.suggest_int('num_leaves', 2,100)
    subsample=trial.suggest_float('subsample',0.5,1.0)
    learning_rate=trial.suggest_float('learning_rate',0.001,0.1)
    colsample_bytree=trial.suggest_float('colsample_bytree',0.5,1.0)



    model = LGBMRegressor(n_estimators=n_estimators,
                         max_depth=max_depth,
                         learning_rate=learning_rate,
                         num_leaves=num_leaves,
                         subsample=subsample,
                         colsample_bytree=colsample_bytree)
    score = cross_val_score(model, X_train,y_train, cv=5, scoring='neg_root_mean_squared_error')
    return score.mean()

study =optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=40, show_progress_bar=True )
# 'n_estimators': 356, 'max_depth': 10, 'num_leaves': 7, 'subsample': 0.7426142421600143, 'learning_rate': 0.02684749252385173, 'colsample_bytree': 0.655631790885152}. Best is trial 39 with value: -39.01980710390345.
# Out:
# [I 2025-02-10 23:29:47,626] A new study created in memory with name: no-name-314eff12-7d27-48fa-8f0e-4bfdb3cf1e2a
#   0%|          | 0/40 [00:00<?, ?it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002018 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.378871
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.491740
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002116 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.456603
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002573 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385122
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385760
# [I 2025-02-10 23:29:49,519] Trial 0 finished with value: -39.02904880953603 and parameters: {'n_estimators': 229, 'max_depth': 12, 'num_leaves': 2, 'subsample': 0.5593030220962327, 'learning_rate': 0.06967850066839319, 'colsample_bytree': 0.7650885048914374}. Best is trial 0 with value: -39.02904880953603.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002050 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.378871
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001920 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.491740
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.456603
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001544 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385122
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385760
# [I 2025-02-10 23:29:56,536] Trial 1 finished with value: -39.08355861899772 and parameters: {'n_estimators': 673, 'max_depth': 10, 'num_leaves': 17, 'subsample': 0.7637972016258631, 'learning_rate': 0.0942443232932206, 'colsample_bytree': 0.6238170366559345}. Best is trial 0 with value: -39.02904880953603.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002222 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.378871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001988 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.491740
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-02-10 23:33:22,834] Trial 38 finished with value: -39.032998524211436 and parameters: {'n_estimators': 355, 'max_depth': 4, 'num_leaves': 48, 'subsample': 0.5938554617367222, 'learning_rate': 0.0529032628135293, 'colsample_bytree': 0.6265970872433402}. Best is trial 23 with value: -39.020561660838425.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001931 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.378871
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001974 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.491740
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002482 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.456603
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002434 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385122
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001964 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 192000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.385760
# [I 2025-02-10 23:33:26,773] Trial 39 finished with value: -39.01980710390345 and parameters: {'n_estimators': 356, 'max_depth': 10, 'num_leaves': 7, 'subsample': 0.7426142421600143, 'learning_rate': 0.02684749252385173, 'colsample_bytree': 0.655631790885152}. Best is trial 39 with value: -39.01980710390345.

# %%
model = LGBMRegressor(n_estimators=356,
                         max_depth=10,
                         learning_rate=0.02684749252385173,
                         num_leaves=7,
                         subsample=0.7426142421600143,
                         colsample_bytree=0.655631790885152)
model.fit(X_train,y_train)
model.predict(X_test_transformed)
submission = pd.DataFrame({
    'id': test_id_col,
    'Price': test_predicted
})
submission.to_csv('submission_lgbm_deletednulls.csv', index=False)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 320
# [LightGBM] [Info] Number of data points in the train set: 240000, number of used features: 27
# [LightGBM] [Info] Start training from score 81.419619

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostRegressor
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.metrics import root_mean_squared_error

def objective(trial):
    n_estimators=trial.suggest_int('n_estimators',100,1000)
    depth=trial.suggest_int('depth',4,12)
    l2_leaf_reg=trial.suggest_int('l2_leaf_reg',1,10)
    learning_rate=trial.suggest_float('learning_rate', 0.001,0.3)
    subsample=trial.suggest_float('subsample', 0.5,1.0)
    min_data_in_leaf=trial.suggest_int('min_data_in_leaf',1,50)



    model = CatBoostRegressor(n_estimators=n_estimators,
                         depth=depth,
                         learning_rate=learning_rate,
                         l2_leaf_reg=l2_leaf_reg,
                         subsample=subsample,
                         min_data_in_leaf=min_data_in_leaf)
    score = cross_val_score(model, X_train,y_train, cv=5, scoring='neg_root_mean_squared_error')
    return score.mean()

study =optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=60, show_progress_bar=True )
# Trial 54 finished with value: -39.01813791433403 and parameters: {'n_estimators': 159, 'depth': 4, 'l2_leaf_reg': 3, 'learning_rate': 0.10037409967024077, 'subsample': 0.9759101072912689, 'min_data_in_leaf': 44}. Best is trial 54 with value: -39.01813791433403.

# %%
model = CatBoostRegressor(n_estimators=159,
                         depth=4,
                         learning_rate=0.10037409967024077,
                         l2_leaf_reg=3,
                         subsample=0.9759101072912689,
                         min_data_in_leaf=44)
model.fit(X_train,y_train)
model.predict(X_test_transformed)
submission = pd.DataFrame({
    'id': test_id_col,
    'Price': test_predicted
})
submission.to_csv('submission_catboost_nulldropping.csv', index=False)
# Out:
# 0:	learn: 39.0558433	total: 7.61ms	remaining: 1.2s
# 1:	learn: 39.0519520	total: 14.3ms	remaining: 1.12s
# 2:	learn: 39.0491271	total: 20ms	remaining: 1.04s
# 3:	learn: 39.0459779	total: 26ms	remaining: 1s
# 4:	learn: 39.0426335	total: 32.3ms	remaining: 996ms
# 5:	learn: 39.0400634	total: 38.2ms	remaining: 975ms
# 6:	learn: 39.0376313	total: 43.9ms	remaining: 953ms
# 7:	learn: 39.0361997	total: 49.7ms	remaining: 938ms
# 8:	learn: 39.0341793	total: 55.1ms	remaining: 919ms
# 9:	learn: 39.0328555	total: 60.9ms	remaining: 907ms
# 10:	learn: 39.0316032	total: 66.8ms	remaining: 898ms
# 11:	learn: 39.0306221	total: 72.6ms	remaining: 890ms
# 12:	learn: 39.0294985	total: 78.4ms	remaining: 880ms
# 13:	learn: 39.0282743	total: 83.8ms	remaining: 868ms
# 14:	learn: 39.0272559	total: 89.3ms	remaining: 857ms
# 15:	learn: 39.0262282	total: 95.8ms	remaining: 856ms
# 16:	learn: 39.0253401	total: 102ms	remaining: 851ms
# 17:	learn: 39.0249375	total: 107ms	remaining: 841ms
# 18:	learn: 39.0239069	total: 113ms	remaining: 835ms
# 19:	learn: 39.0231524	total: 119ms	remaining: 830ms
# 20:	learn: 39.0224822	total: 125ms	remaining: 822ms
# 21:	learn: 39.0218637	total: 131ms	remaining: 818ms
# 22:	learn: 39.0212572	total: 138ms	remaining: 816ms
# 23:	learn: 39.0205441	total: 144ms	remaining: 808ms
# 24:	learn: 39.0200523	total: 149ms	remaining: 800ms
# 25:	learn: 39.0192866	total: 156ms	remaining: 796ms
# 26:	learn: 39.0185354	total: 161ms	remaining: 788ms
# 27:	learn: 39.0177880	total: 167ms	remaining: 780ms
# 28:	learn: 39.0171168	total: 172ms	remaining: 772ms
# 29:	learn: 39.0166407	total: 179ms	remaining: 768ms
# 30:	learn: 39.0158599	total: 184ms	remaining: 761ms
# 31:	learn: 39.0151492	total: 190ms	remaining: 754ms
# 32:	learn: 39.0148168	total: 196ms	remaining: 748ms
# 33:	learn: 39.0141661	total: 201ms	remaining: 741ms
# 34:	learn: 39.0135051	total: 209ms	remaining: 739ms
# 35:	learn: 39.0130788	total: 215ms	remaining: 733ms
# 36:	learn: 39.0128368	total: 220ms	remaining: 726ms
# 37:	learn: 39.0122800	total: 229ms	remaining: 730ms
# 38:	learn: 39.0118743	total: 236ms	remaining: 725ms
# 39:	learn: 39.0111037	total: 241ms	remaining: 716ms
# 40:	learn: 39.0104667	total: 246ms	remaining: 709ms
# 41:	learn: 39.0102160	total: 252ms	remaining: 702ms
# 42:	learn: 39.0095060	total: 258ms	remaining: 695ms
# 43:	learn: 39.0090826	total: 263ms	remaining: 688ms
# 44:	learn: 39.0086828	total: 269ms	remaining: 682ms
# 45:	learn: 39.0081749	total: 275ms	remaining: 675ms
# 46:	learn: 39.0078379	total: 281ms	remaining: 670ms
# 47:	learn: 39.0074316	total: 287ms	remaining: 664ms
# 48:	learn: 39.0071124	total: 293ms	remaining: 658ms
# 49:	learn: 39.0068247	total: 299ms	remaining: 652ms
# 50:	learn: 39.0065295	total: 305ms	remaining: 645ms
# 51:	learn: 39.0063037	total: 311ms	remaining: 640ms
# 52:	learn: 39.0059511	total: 317ms	remaining: 634ms
# 53:	learn: 39.0056125	total: 323ms	remaining: 628ms
# 54:	learn: 39.0051549	total: 329ms	remaining: 622ms
# 55:	learn: 39.0047044	total: 335ms	remaining: 615ms
# 56:	learn: 39.0046497	total: 339ms	remaining: 607ms
# 57:	learn: 39.0043456	total: 345ms	remaining: 601ms
# 58:	learn: 39.0038891	total: 351ms	remaining: 595ms
# 59:	learn: 39.0035157	total: 357ms	remaining: 589ms
# 60:	learn: 39.0032161	total: 363ms	remaining: 583ms
# 61:	learn: 39.0027967	total: 369ms	remaining: 577ms
# 62:	learn: 39.0024561	total: 375ms	remaining: 572ms
# 63:	learn: 39.0020891	total: 381ms	remaining: 565ms
# 64:	learn: 39.0017161	total: 386ms	remaining: 559ms
# 65:	learn: 39.0011144	total: 392ms	remaining: 552ms
# 66:	learn: 39.0006833	total: 397ms	remaining: 545ms
# 67:	learn: 39.0000620	total: 402ms	remaining: 538ms
# 68:	learn: 38.9997856	total: 408ms	remaining: 532ms
# 69:	learn: 38.9996253	total: 414ms	remaining: 526ms
# 70:	learn: 38.9994909	total: 420ms	remaining: 520ms
# 71:	learn: 38.9991911	total: 427ms	remaining: 517ms
# 72:	learn: 38.9989627	total: 434ms	remaining: 511ms
# 73:	learn: 38.9985888	total: 439ms	remaining: 505ms
# 74:	learn: 38.9984274	total: 446ms	remaining: 500ms
# 75:	learn: 38.9982307	total: 452ms	remaining: 494ms
# 76:	learn: 38.9978805	total: 458ms	remaining: 488ms
# 77:	learn: 38.9975065	total: 464ms	remaining: 482ms
# 78:	learn: 38.9972709	total: 470ms	remaining: 476ms
# 79:	learn: 38.9969882	total: 475ms	remaining: 469ms
# 80:	learn: 38.9968075	total: 481ms	remaining: 463ms
# 81:	learn: 38.9965335	total: 488ms	remaining: 458ms
# 82:	learn: 38.9963069	total: 494ms	remaining: 452ms
# 83:	learn: 38.9959520	total: 500ms	remaining: 447ms
# 84:	learn: 38.9953780	total: 506ms	remaining: 440ms
# 85:	learn: 38.9950826	total: 512ms	remaining: 434ms
# 86:	learn: 38.9949175	total: 517ms	remaining: 428ms
# 87:	learn: 38.9945535	total: 525ms	remaining: 424ms
# 88:	learn: 38.9943650	total: 532ms	remaining: 418ms
# 89:	learn: 38.9941253	total: 538ms	remaining: 413ms
# 90:	learn: 38.9936851	total: 544ms	remaining: 407ms
# 91:	learn: 38.9932579	total: 551ms	remaining: 401ms
# 92:	learn: 38.9929008	total: 556ms	remaining: 395ms
# 93:	learn: 38.9927717	total: 562ms	remaining: 389ms
# 94:	learn: 38.9922627	total: 568ms	remaining: 383ms
# 95:	learn: 38.9919935	total: 574ms	remaining: 377ms
# 96:	learn: 38.9916633	total: 580ms	remaining: 371ms
# 97:	learn: 38.9913989	total: 585ms	remaining: 364ms
# 98:	learn: 38.9912864	total: 592ms	remaining: 359ms
# 99:	learn: 38.9908409	total: 598ms	remaining: 353ms
# 100:	learn: 38.9905550	total: 605ms	remaining: 347ms
# 101:	learn: 38.9902772	total: 612ms	remaining: 342ms
# 102:	learn: 38.9900590	total: 619ms	remaining: 336ms
# 103:	learn: 38.9896921	total: 625ms	remaining: 331ms
# 104:	learn: 38.9892980	total: 632ms	remaining: 325ms
# 105:	learn: 38.9890485	total: 638ms	remaining: 319ms
# 106:	learn: 38.9886074	total: 644ms	remaining: 313ms
# 107:	learn: 38.9882798	total: 650ms	remaining: 307ms
# 108:	learn: 38.9881478	total: 656ms	remaining: 301ms
# 109:	learn: 38.9878577	total: 661ms	remaining: 295ms
# 110:	learn: 38.9874865	total: 667ms	remaining: 289ms
# 111:	learn: 38.9868658	total: 673ms	remaining: 282ms
# 112:	learn: 38.9865411	total: 678ms	remaining: 276ms
# 113:	learn: 38.9862262	total: 684ms	remaining: 270ms
# 114:	learn: 38.9859371	total: 690ms	remaining: 264ms
# 115:	learn: 38.9856756	total: 697ms	remaining: 258ms
# 116:	learn: 38.9853945	total: 702ms	remaining: 252ms
# 117:	learn: 38.9850729	total: 708ms	remaining: 246ms
# 118:	learn: 38.9848431	total: 714ms	remaining: 240ms
# 119:	learn: 38.9845596	total: 720ms	remaining: 234ms
# 120:	learn: 38.9841318	total: 726ms	remaining: 228ms
# 121:	learn: 38.9836860	total: 732ms	remaining: 222ms
# 122:	learn: 38.9833503	total: 738ms	remaining: 216ms
# 123:	learn: 38.9830523	total: 744ms	remaining: 210ms
# 124:	learn: 38.9827573	total: 750ms	remaining: 204ms
# 125:	learn: 38.9824529	total: 756ms	remaining: 198ms
# 126:	learn: 38.9820948	total: 762ms	remaining: 192ms
# 127:	learn: 38.9813323	total: 768ms	remaining: 186ms
# 128:	learn: 38.9809970	total: 774ms	remaining: 180ms
# 129:	learn: 38.9805137	total: 779ms	remaining: 174ms
# 130:	learn: 38.9801973	total: 785ms	remaining: 168ms
# 131:	learn: 38.9798938	total: 791ms	remaining: 162ms
# 132:	learn: 38.9794082	total: 796ms	remaining: 156ms
# 133:	learn: 38.9791455	total: 802ms	remaining: 150ms
# 134:	learn: 38.9787859	total: 809ms	remaining: 144ms
# 135:	learn: 38.9784496	total: 815ms	remaining: 138ms
# 136:	learn: 38.9779002	total: 820ms	remaining: 132ms
# 137:	learn: 38.9773728	total: 827ms	remaining: 126ms
# 138:	learn: 38.9770865	total: 833ms	remaining: 120ms
# 139:	learn: 38.9767013	total: 839ms	remaining: 114ms
# 140:	learn: 38.9762934	total: 846ms	remaining: 108ms
# 141:	learn: 38.9759303	total: 852ms	remaining: 102ms
# 142:	learn: 38.9756391	total: 858ms	remaining: 96ms
# 143:	learn: 38.9751254	total: 864ms	remaining: 90ms
# 144:	learn: 38.9747365	total: 871ms	remaining: 84.1ms
# 145:	learn: 38.9741279	total: 877ms	remaining: 78.1ms
# 146:	learn: 38.9737852	total: 884ms	remaining: 72.1ms
# 147:	learn: 38.9734406	total: 890ms	remaining: 66.1ms
# 148:	learn: 38.9731859	total: 896ms	remaining: 60.1ms
# 149:	learn: 38.9727624	total: 902ms	remaining: 54.1ms
# 150:	learn: 38.9724980	total: 908ms	remaining: 48.1ms
# 151:	learn: 38.9719599	total: 914ms	remaining: 42.1ms
# 152:	learn: 38.9716232	total: 920ms	remaining: 36.1ms
# 153:	learn: 38.9712288	total: 926ms	remaining: 30.1ms
# 154:	learn: 38.9709592	total: 933ms	remaining: 24.1ms
# 155:	learn: 38.9705119	total: 940ms	remaining: 18.1ms
# 156:	learn: 38.9700844	total: 946ms	remaining: 12ms
# 157:	learn: 38.9697151	total: 952ms	remaining: 6.03ms
# 158:	learn: 38.9693148	total: 959ms	remaining: 0us
